# %%
# %matplotlib inline

# %%
import xarray as xr

# %%
scam_path = "../data/output/scam.nc"
ngaqua_path = "../data/raw/2/NG_5120x2560x34_4km_10s_QOBS_EQX/coarse/2d/all.nc"

x = 100

# %%
ng = xr.open_dataset(ngaqua_path).sortby('time')
scam = xr.open_dataset(scam_path).sortby('time')

# %%
scam.SOLIN.isel(x=x).plot(label='SCAM', marker='o')
ng.SOLIN.isel(x=x).sel(y=scam.y).plot(label='NG', marker='o')

plt.legend()
plt.xlim([102, 103])
plt.axvline(102.5)
# Out:
# /Users/noah/anaconda/envs/uw-machine-learning/lib/python3.6/site-packages/xarray/plot/utils.py:51: FutureWarning: 'pandas.tseries.converter.register' has been moved and renamed to 'pandas.plotting.register_matplotlib_converters'.
#   converter.register()

# %% [markdown]
# This is pretty close. What is account for the delay between these curves? They seem shifted slightly with respect to each other. Ah yes. This is because the SCAM outputs SOLIN as a time average over the previous output interval.
